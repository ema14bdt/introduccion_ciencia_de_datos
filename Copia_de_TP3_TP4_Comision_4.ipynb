# %% [markdown]
# <a href="https://colab.research.google.com/github/ema14bdt/introduccion_ciencia_de_datos/blob/main/Copia_de_TP3_TP4_Comision_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TRABAJO PRACTICO N 3

# %% [markdown]
# ***TEMAS A DESARROLLAR:***
#
# Nociones de Probabilidad, simulación de procesos aleatorios, cálculo de parámetros estadisticos: Media o Valor Esperado(PROMEDIO), Mediana, Desvio Estandar. DISTRIBUCIONES DE PROABABILIDAD más frecuentes, por ejemplo la Normal.

# %% [markdown]
# ## Funciones estadísticas para análisis exploratorio de datos
# A continuación se presentan ejemplos de funciones estadísticas para el análisis exploratorio de datos utilizando NumPy:

# %% [markdown]
# #### Crear array aleatorio
# En esta celda, se utiliza la función np.random.rand() de NumPy para crear un array de números aleatorios con una forma específica. Luego, se imprime el array.

# %%
import numpy as np
random_array = np.random.randint(0,10, (4,3))
print("Array aleatorio:", random_array)
# Out:
# [[3 0 4]
#  [2 0 6]
#  [2 3 5]
#  [8 9 2]]

# %% [markdown]
# #### Media
# En esta celda, se crea un array 'array' y se utiliza la función np.mean() de NumPy para calcular la media del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
media = np.mean(array)
print("Media:", media)
# Out:
# Media: 3.0

# %% [markdown]
# #### Desviación estándar
# En esta celda, se crea un array 'array' y se utiliza la función np.std() de NumPy para calcular la desviación estándar del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
desviacion_estandar = np.std(array)
print("Desviación estándar:", desviacion_estandar)
# Out:
# Desviación estándar: 1.4142135623730951

# %% [markdown]
# #### Varianza
# La función np.var() se utiliza para calcular la varianza de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
varianza = np.var(array)
print("Varianza:", varianza)
# Out:
# Varianza: 2.0

# %% [markdown]
# #### Valor mínimo
# En esta celda, se crea un array 'array' y se utiliza la función np.min() de NumPy para encontrar el valor mínimo del array. Luego, se imprime el resultado.

# %%
array = np.array([1, 2, 3, 4, 5])
matriz=np.random.randint(-3,3,(5,5))
#minimo = np.min(array)
minimo = np.min(matriz, axis=0)
print("Valor mínimo:", minimo)
print( matriz)
# Out:
# Valor mínimo: [-3 -3 -3 -3 -3]
# [[ 1 -3  0 -3  0]
#  [-1  2 -2  0 -2]
#  [-3 -1 -3  0 -2]
#  [-3 -2 -2 -2 -3]
#  [-3  0  1  0  1]]

# %% [markdown]
# #### Valor máximo
# En esta celda, se crea un array 'array' y se utiliza la función np.max() de NumPy para encontrar el valor máximo del array. Luego, se imprime el resultado.

# %%
maximo = np.max(array)
print("Valor máximo:", maximo)
# Out:
# Valor máximo: 5

# %% [markdown]
# #### Gráfico de dispersión
# En esta celda, se crea un array 'x' con valores aleatorios y un array 'y' con valores aleatorios. Luego, se utiliza la biblioteca Matplotlib para trazar un gráfico de dispersión con 'x' en el eje x y 'y' en el eje y. También se agrega etiquetas y un título al gráfico.

# %%
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de dispersión')
plt.show()

# %% [markdown]
# En esta celda, se crea un array 'data' con valores aleatorios siguiendo una distribución normal. Luego, se utiliza la biblioteca Matplotlib para trazar un histograma de 'data'. También se agrega etiquetas y un título al gráfico.

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %% [markdown]
# #### Mediana
# La función np.median() se utiliza para calcular la mediana de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
mediana = np.median(array)
print("Mediana:", mediana)
# Out:
# Mediana: 3.0

# %% [markdown]
# #### Percentiles
# La función np.percentile() se utiliza para calcular los percentiles de un array.
# Ejemplo de uso:

# %%
array = np.array([1, 2, 3, 4, 5])
percentil_50 = np.percentile(array, 50)
print("Percentil 50:", percentil_50)
# Out:
# Percentil 50: 3.0

# %% [markdown]
# # EJEMPLOS Y APLICACIÓNES

# %% [markdown]
# ***APLICACIÓN DE PROBABILIDAD***
#
# Se Realiza el lanzamiento de un dado EQUILIBRADO JUSTO, de manera reiterada con las mismas condiciones, y se anotan sus resultados= CARA O CRUZ.
#
# Se le pide al usuario que defina la cantidad N de lanzamientos y se calcula su frecuencia relativa= 'PROBABILIDAD' de obtener cara o cruz. Se obtiene los siguientes resultados:

# %%
import numpy as np
n=int(input('ingrese la cantidad de simulación o lanzamientos: '))

#========= FORMA 1 DE SIMULAR LANZAMIENTO DE UN DADO============
dado=[]
cara=0
cruz=0
for i in range(n):
  dado.append(np.random.rand(1))
  dado1=np.array(dado)
  if dado1[i]<0.5:
    #print('salio cara')
    #print(dado[i])
    cara +=1
  else:
    #print('salio cruz')
    #print(dado[i])
    cruz +=1
# Out:
# ingrese la cantidad de simulación o lanzamientos: 200

# %%
#  mostrar la probailidad frecuencista de el lanzamiento de un dado
prom_cara=cara/n
prom_cruz=cruz/n
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CARA es:', prom_cara)
print('la probabilidad aproximada en '+str(n)+' lanzamientos de sacar CRUZ es:', prom_cruz)
# Out:
# la probabilidad aproximada en 200 lanzamientos de sacar CARA es: 0.53
# la probabilidad aproximada en 200 lanzamientos de sacar CRUZ es: 0.47

# %%
#========== FORMA COMPACTA DE SIMULAR USANDO NUMPY===========
m=int(input('ingrese la cantidad de simulación o lanzamientos: '))
lanzamientos = np.random.randint(0, 2, m)

# Calcular las probabilidades

probabilidad_cara = np.sum(lanzamientos ==0 ) / len(lanzamientos)
probabilidad_sello = np.sum(lanzamientos== 1) / len(lanzamientos)

print(f"Probabilidad de cara: {probabilidad_cara:.2f}")
print(f"Probabilidad de sello: {probabilidad_sello:.2f}")
# Out:
# ingrese la cantidad de simulación o lanzamientos200
# Probabilidad de cara: 0.52
# Probabilidad de sello: 0.48

# %%
import matplotlib.pyplot as plt
x=np.array(range(2))
y=np.array([probabilidad_cara, probabilidad_sello])

plt.bar(x,y)
plt.xlabel('Opción')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma del lanzamiento de una moneda equilibrada')
plt.show()

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ##***EJERCICIO 1***
#
# Simular el lanzamiento de un dado eqilibrado de 6 caras.
#
#
# *   Mostrar la probabilida aproximada de obtener el número 2, 3 y 5
# *   Graficar el histograma de las probabilidades

# %%
import numpy as np

# Mostrar la probabilida aproximada de obtener el número 2, 3 y 5

m = int(input('Ingrese la cantidad de simulación o lanzamientos: '))
lanzamientos = np.random.randint(1, 7, m)

probabilidad_2 = np.sum(lanzamientos == 2 ) / len(lanzamientos)
probabilidad_3 = np.sum(lanzamientos == 3) / len(lanzamientos)
probabilidad_5 = np.sum(lanzamientos == 5) / len(lanzamientos)

print(f"Probabilidad de obtener el número 2: {probabilidad_2:.2f}")
print(f"Probabilidad de obtener el número 3: {probabilidad_3:.2f}")
print(f"Probabilidad de obtener el número 5: {probabilidad_5:.2f}")
# Out:
# Ingrese la cantidad de simulación o lanzamientos: 90
# Probabilidad de obtener el número 2: 0.16
# Probabilidad de obtener el número 3: 0.14
# Probabilidad de obtener el número 5: 0.21

# %%
import matplotlib.pyplot as plt

# Graficar el histograma de las probabilidades

x = [1, 2, 3, 4, 5, 6]
y = [np.sum(lanzamientos == x) for x in x]

plt.bar(x,y)
plt.xlabel('Valor del dado')
plt.ylabel('Frecuencia')
plt.title(f'Histograma de {m} lanzamientos de un dado')
plt.show()

# %% [markdown]
# ## EJERCICIO 4
#
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2- Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.
#
#
# 1.   Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.
# 2.    Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.
# 3.   Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.
# 4.   Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro *'DESVIO ESTANDAR'*

# %%
# Dada la base de datos de ventas diarias durante una semana, de un negocio con 4 productos.- VER EJERCICIO PARTE 2 PRACTICO N 2-
# Realizar el siguiente análisis de datos para poder obtener información y planificar una estrategia de ventas.

import numpy as np

data = np.array([
    [20, 15, 25, 30, 18, 22, 24],
    [12, 20, 14, 8, 15, 18, 16],
    [35, 28, 32, 30, 26, 24, 30],
    [40, 38, 45, 42, 39, 41, 37]
])

subtotal = np.array([107, 101, 116, 110, 98, 105, 105])

productos = ['A', 'B', 'C', 'D']
dias_semana = ['Lun', 'Mar', 'Mie', 'Jue', 'Vie', 'Sab', 'Dom']

# %%
# 1) Calcular la media en la ventas por cada producto y la mediana. Plotear estos nuevos datos en un gráfico de barra.

media_ventas = np.mean(data, axis=1)
mediana_ventas = np.median(data, axis=1)

x = np.arange(len(productos))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, media_ventas, width, label='Media')
rects2 = ax.bar(x + width/2, mediana_ventas, width, label='Mediana')

ax.set_ylabel('Ventas')
ax.set_title('Media y Mediana de Ventas por Producto')
ax.set_xticks(x)
ax.set_xticklabels(productos)
ax.legend()

plt.show()

# %%
# 2) Calcular la media en la ventas por DÍA y la mediana. Plotear estos nuevos datos en un gráfico de TRAZO DE LINEAS.

media_ventas_dia = np.mean(data, axis=0)
mediana_ventas_dia = np.median(data, axis=0)

plt.plot(dias_semana, media_ventas_dia, marker='o', label='Media')
plt.plot(dias_semana, mediana_ventas_dia, marker='o', label='Mediana')

plt.xlabel('Día de la semana')
plt.ylabel('Ventas')
plt.title('Media y Mediana de Ventas por Día de la Semana')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# 3) Realizar una conclusión en función las graficas y sugerir al menos 5 estrategias de venta o inversión de manera de potenciar este negocio.

'''
Conclusiones:

Variación en productos: Productos A y D lideran las ventas; B muestra ventas bajas; C es consistente.
Variación por día: Ventas altas miércoles, disminuyen jueves-domingo.
Media vs. mediana: Posibles valores atípicos influyendo en las diferencias.
Estrategias de Venta e Inversión:

Promoción de Producto B: Descuentos y promociones para aumentar ventas de B.

Optimización de Inventario: Ajustar inventario según días de demanda.

Fidelización en Días Altos: Programas de lealtad en días con ventas altas.

Diversificación de Productos: Expandir oferta para abarcar más segmentos.

Optimización de Horarios: Ajustar horarios según días de alta demanda.

Gestión de Valores Atípicos: Investigar y abordar causas de variaciones notables.
'''

# %%
# 4) Calcular el desvio estandar de los datos por cada producto y concluir para cada producto como es su rango de variabilidad en las ventas de los mismos.
# Plotear los datos de ventas de la semana de los productos con mayor y menor desvio estandar y evidenciar la variabilidad indicada en el parametro 'DESVIO ESTANDAR'


desvio_estandar_ventas = np.std(data, axis=1)

indice_max_desvio = np.argmax(desvio_estandar_ventas)
indice_min_desvio = np.argmin(desvio_estandar_ventas)

producto_mayor_desvio = productos[indice_max_desvio]
producto_menor_desvio = productos[indice_min_desvio]

plt.figure(figsize=(10, 6))
plt.boxplot(data.T, labels=productos)
plt.title('Variabilidad en Ventas por Producto')
plt.xlabel('Producto')
plt.ylabel('Ventas')
plt.grid(True)
plt.xticks(rotation=45)

plt.annotate('Mayor Desvío\n' + producto_mayor_desvio,
             xy=(indice_max_desvio + 1, data.max()),
             xytext=(indice_max_desvio + 1, data.max() + 10),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, ha='center')

plt.annotate('Menor Desvío\n' + producto_menor_desvio,
             xy=(indice_min_desvio + 1, data.min()),
             xytext=(indice_min_desvio + 1, data.min() - 15),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## EJERCICIO 5
#
# Solicitar al usuario que ingrese la cantidad N de datos a cargar. Luego generar de manera aleatoria los siguientes datos:
#
# * SEXO= 'MASCULINO', 'FEMENINO','NO ESPECIFICA'
# * EDAD= entre 28 y 60 años
# * ALTURA= entre un rango de 165.0 mts hasta 210 mts
# * PESO= entre un rango de 50  y 110 kg
# * HORAS DE DESCANSO diario= un número decimal
# * HORAS DE TRABAJO/ ESTUDIO diario= un número decimal
# * HORAS DE EJERCICIOS diario= un número decimal
#
# REalizar las siguientes indicaciones y extraer concluisiones sobre la información y la pooblación muestreada.
#
# 1.   Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
# 2.   Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
# 3.  Graficar la muestra o distribución de los datos  de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
# 4.  Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
# 5. Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio

# %% [markdown]
# **Ayuda Como generar los datos**

# %%
import numpy as np
import matplotlib.pyplot as plt

def generar_datos(N):
    sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], N ,[0.4, 0.5, 0.1])  # Por ejemplo, 40% masculino, 50% femenino, 10% no especificado)
    # Generar edades con distribución normal
    edad =np.random.normal(44, 6, N)
    edad=np.clip(np.around(edad),28,60)
    # Generar alturas, pesos y otras características
    altura = np.random.normal(180, 10, N)
    altura = np.clip(np.around(altura, decimals=1), 150.0, 210.0)

    peso = np.random.normal(80, 15, N)
    peso = np.clip(np.around(peso, decimals=1), 40.0, 130.0)

    horas_trabajo_estudio = np.random.normal(10, 2, N)
    horas_trabajo_estudio = np.clip(np.around(horas_trabajo_estudio, decimals=1), 4.0, 12.0)

    horas_ejercicio = np.random.normal(1, 0.5, N)
    horas_ejercicio = np.clip(np.around(horas_ejercicio, decimals=1), 0, 2)

    horas_descanso = 24 - horas_trabajo_estudio - horas_ejercicio
    datos = np.column_stack((sexo, edad, altura, peso, horas_descanso, horas_trabajo_estudio, horas_ejercicio))
    return datos


# Solicitar al usuario la cantidad N de datos a cargar
N = 1000

# Generar datos aleatorios para N personas con distribución normal y límites específicos
datos = generar_datos(N)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Generar un array de dimensión 2 (matriz), con todos los datos ordenados, permitiendo visualizarlos como tabla.
N = int(input("Ingrese la cantidad de datos a cargar: "))

np.random.seed(42)

sexo = np.random.choice(['MASCULINO', 'FEMENINO', 'NO ESPECIFICA'], size=N)
edad = np.random.randint(28, 61, size=N)
altura = np.random.uniform(165.0, 210.0, size=N)
peso = np.random.uniform(50, 110, size=N)
horas_descanso = np.random.uniform(4, 10, size=N)
horas_trabajo_estudio = np.random.uniform(2, 12, size=N)
horas_ejercicio = np.random.uniform(0.5, 3, size=N)
# Out:
# Ingrese la cantidad de datos a cargar: 10

# %%
# 2) Suponiendo que la distribución de probabilidad de los datos muestrados de las N personas, se distribuyen en forma NORMAL. Encontrar la media en los datos de altura, peso, y horas de descanso, trabajo y ejercicios.
media_altura = np.mean(altura)
media_peso = np.mean(peso)
media_horas_descanso = np.mean(horas_descanso)
media_horas_trabajo_estudio = np.mean(horas_trabajo_estudio)
media_horas_ejercicio = np.mean(horas_ejercicio)

# %%
# 3) Graficar la muestra o distribución de los datos de pesos , y alturas en graficas separadas. Indicar el grado de variabilidad de sus datos
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(peso, bins=20, color='blue', edgecolor='black')
plt.title('Distribución de Pesos')
plt.xlabel('Peso')
plt.ylabel('Frecuencia')

plt.subplot(1, 2, 2)
plt.hist(altura, bins=20, color='green', edgecolor='black')
plt.title('Distribución de Alturas')
plt.xlabel('Altura')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
# 4) Plotear de manera conjunta y encontrar si presentan correlación los datos de peso vs altura,
plt.figure(figsize=(6, 6))
plt.scatter(peso, altura, color='red')
plt.title('Correlación entre Peso y Altura')
plt.xlabel('Peso')
plt.ylabel('Altura')
plt.grid(True)
plt.show()

# %%
# 5) Plotear de manera conjunta los datos de horas de descanso, estudio y ejercicio
plt.figure(figsize=(8, 6))
plt.plot(horas_descanso, label='Horas de Descanso')
plt.plot(horas_trabajo_estudio, label='Horas de Trabajo/Estudio')
plt.plot(horas_ejercicio, label='Horas de Ejercicio')
plt.title('Horas de Descanso, Trabajo/Estudio y Ejercicio')
plt.xlabel('Personas')
plt.ylabel('Horas')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # TRABAJO PRACTICO N 4

# %% [markdown]
# **Trabajo Practico Nº 4**
# Analisis sobre data set
#
# 1= Buscar los siguiente data set en la web
# * Titanic
# * Iris
# * Wine
# * Indian Diabetes
#
# 2- Explicar un data set , sus diferente Variables\
# 3- Deside justificando tu respuesta que tipo de categoria de variable son\
# 4- Detectar y arreglar los siguientes coceptos
# * Valores Ausente
# * Valores Atipicos
#
# 5- Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?\
#
# 6- Realizar analisis univariados
# * Grafico de frecuencia
# * Grafico de torta
# * Histograma
# * etc
#
# 7- En base a los graficos del punto 6 realizar distintas concluciones\
#
# 8- Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\
#
# PD Pueden Buscar data set de kaggle

# %% [markdown]
# **2- Explicar un data set , sus diferente Variables**
#
# Este conjunto de datos es utilizado para ejemplos de clasificación y clustering. Contiene medidas de longitud y ancho de los pétalos y sépalos de tres especies diferentes de iris: setosa, versicolor y virginica.
#
# Variables en el conjunto de datos Iris:
#
# sepal.length: Longitud del sépalo en centímetros.
# sepal.width: Ancho del sépalo en centímetros.
# petal.length: Longitud del pétalo en centímetros.
# petal.width: Ancho del pétalo en centímetros.
# variety: Especie de iris (setosa, versicolor o virginica).

# %% [markdown]
# **3- Decide justificando tu respuesta que tipo de categoria de variable son**
#
# sepal.length, sepal.width, petal.length y petal.width son variables numéricas continuas ya que tiene valores numéricos que representan dimensiones.
# variety es una variable categórica nominal ya que puede tomar los valores setosa, versicolor o virginica y no pueden tener valores numéricos.

# %%
'''
4- Detectar y arreglar los siguientes coceptos

Valores Ausente
Valores Atipicos
'''

import pandas as pd

url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
df = pd.read_csv(url)
df.head()

# Eliminar valores nulos
df_cleaned = df.dropna()
# Valores atipicos
df.boxplot()

def detect_outliers_iqr(data, column):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

# Detectar valores atipicos en la columna 'sepal.width'
columns_to_check = ["sepal.width"]
outliers_list = []
for column in columns_to_check:
    outliers = detect_outliers_iqr(df, column)
    outliers_list.append(outliers)

# Concatenamos los outliers
outliers_df = pd.concat(outliers_list)

# Eliminamos los outliers del conjunto de datos original
data_cleaned = df.drop(outliers_df.index)

print("Outliers detectados:", len(outliers_df))
# Out:
# Outliers detectados: 4

# %% [markdown]
# 5- Sobre el dataset elegido , ¿se puede eliminar alguna fila o columna?
#
# Es preferible no eliminar ninguna fila para obtener una imagen completa de las características.

# %%
# 6- Realizar analisis univariados

import matplotlib.pyplot as plt

# Grafico de frecuencia

df['variety'].value_counts().plot(kind='bar')
plt.xlabel('Variety')
plt.ylabel('Frequency')
plt.title('Frequency Analysis: Species')
plt.show()

# %%
# Grafico de torta

df['variety'].value_counts().plot(kind='pie')
plt.xlabel('Variety')
plt.title('Frequency Analysis: Species')
plt.show()

# %%
# Historigrama

fig, axs = plt.subplots(4, 2, figsize=(12, 10))

# Histograma y boxplot para sepal.length
axs[0, 0].hist(data_cleaned['sepal.length'])
axs[0, 0].set_xlabel('Sepal Length')
axs[0, 0].set_title('Histogram: Sepal Length')

axs[0, 1].boxplot(data_cleaned['sepal.length'],vert=False)
axs[0, 1].set_xlabel('Sepal Length')
axs[0, 1].set_title('Boxplot: Sepal Length')

# Histograma y boxplot para sepal.width
axs[1, 0].hist(data_cleaned['sepal.width'])
axs[1, 0].set_xlabel('Sepal Width')
axs[1, 0].set_title('Histogram: Sepal Width')

axs[1, 1].boxplot(data_cleaned['sepal.width'],vert=False)
axs[1, 1].set_xlabel('Sepal Width')
axs[1, 1].set_title('Boxplot: Sepal Width')

# Histograma y boxplot para petal.length
axs[2, 0].hist(data_cleaned['petal.length'])
axs[2, 0].set_xlabel('Petal Length')
axs[2, 0].set_title('Histogram: Petal Length')

axs[2, 1].boxplot(data_cleaned['petal.length'],vert=False)
axs[2, 1].set_xlabel('Petal Length')
axs[2, 1].set_title('Boxplot: Petal Length')

# Histograma y boxplot para "petal.width
axs[3, 0].hist(data_cleaned['petal.width'])
axs[3, 0].set_xlabel('petal Width')
axs[3, 0].set_title('Histogram: petal Width')

axs[3, 1].boxplot(data_cleaned['petal.width'],vert=False)
axs[3, 1].set_xlabel('petal Width')
axs[3, 1].set_title('Boxplot: petal Width')

plt.tight_layout()
plt.show()

# %% [markdown]
# **8- Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas**

# %%
'''
                | Sepal Length | Sepal Width | Petal Length | Petal Width |
---------------------------------------------------------------------------
Sepal Length    |    1.000000  |   -0.117570 |    0.871754  |    0.817941  |
Sepal Width     |   -0.117570  |    1.000000 |   -0.428440  |   -0.366126  |
Petal Length    |    0.871754  |   -0.428440 |    1.000000  |    0.962865  |
Petal Width     |    0.817941  |   -0.366126 |    0.962865  |    1.000000  |
---------------------------------------------------------------------------
'''

# %% [markdown]
# - Sepal Length vs. Sepal Width: La correlación entre la longitud del sépalo y el ancho del sépalo es cercana a cero (-0.117570), lo que sugiere una correlación muy débil o prácticamente inexistente entre estas dos variables.
#
# - Sepal Length vs. Petal Length y Petal Width: La longitud del sépalo muestra una correlación positiva significativa con la longitud del pétalo (0.871754) y el ancho del pétalo (0.817941). Esto indica que a medida que la longitud del sépalo aumenta, tiende a aumentar tanto la longitud como el ancho del pétalo.
#
# - Sepal Width vs. Petal Length y Petal Width: La correlación entre el ancho del sépalo y la longitud del pétalo (-0.428440) y el ancho del pétalo (-0.366126) es negativa, lo que sugiere que a medida que el ancho del sépalo aumenta, la longitud y el ancho del pétalo tienden a disminuir.
#
# - Petal Length vs. Petal Width: La correlación entre la longitud y el ancho del pétalo es muy alta (0.962865), lo que indica una fuerte correlación positiva. Esto sugiere que a medida que la longitud del pétalo aumenta, también lo hace su ancho, y viceversa.
